# %% [markdown]
# # 04 - Evaluación y Validación Temporal
# Walk-forward validation por temporadas.

# %%
import sys
sys.path.append("../")

from src.models.evaluate import evaluate_full

results = evaluate_full()
results["results"]

# %%
from IPython.display import Image
Image(filename="../reports/metrics_by_year.png")
